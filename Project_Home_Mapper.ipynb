# %% [markdown]
# ## Stage 1: Training & Testing Layout_Generation_Lited

# %% [markdown]
# ### 1. Project Cloning

# %%
# !git clone https://github.com/AbdulRafay517/Project-Home-Mapper.git
# %cd Project-Home-Mapper/LayoutGenerator_Lited
# Out:
# Cloning into 'Project-Home-Mapper'...
# remote: Enumerating objects: 1493, done.
# remote: Counting objects: 100% (1493/1493), done.
# remote: Compressing objects: 100% (1390/1390), done.
# remote: Total 1493 (delta 88), reused 1488 (delta 86), pack-reused 0 (from 0)
# Receiving objects: 100% (1493/1493), 6.02 MiB | 20.83 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# /content/Project-Home-Mapper/LayoutGenerator_Lited

# %% [markdown]
# ### 2. Downloading & Installing Libraries

# %%
# !pip install torch torchvision easydict numpy shapely open3d
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 84.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 98.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### 3. Downloading Dataset

# %%
# Install gdown to download from Google Drive
# !pip install gdown
# Download the dataset file
# !gdown --id 1DCMdZiLoS2W6-uZb91yk2SgQZcP6rko8
# Unzip
# !unzip MultiLayerDataset.zip -d ./data/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_pair_points_316.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_pair_points_325.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_hull_points_200.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_pair_points_198.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_pair_points_51.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_init_contour_365.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_pair_points_137.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_indicator_values_314.npy
#  extracting: ./data/MultiLayerDataset/EvaluatorData/layers_hull_data/layers_hull_points_238.npy
# ...

# %% [markdown]
# ### 4. Layout Generation

# %%
# !python main.py --cfg cfg/layout_generator.yml --gpu 0
# Out:
# Streaming output truncated to the last 5000 lines.
#         [0.3008, 0.5469, 0.0000, 0.0000]], device='cuda:0')
# refine_layout0: tensor([[0.5189, 0.4828, 0.9234, 0.9205],
#         [0.4677, 0.4963, 0.0454, 0.0299],
#         [0.5499, 0.4071, 0.9227, 0.8901],
#         [0.5621, 0.4307, 0.0468, 0.0432],
#         [0.4819, 0.4494, 0.9245, 0.0333],
#         [0.4966, 0.4235, 0.9465, 0.0439],
#         [0.5227, 0.4472, 0.0517, 0.0389]], device='cuda:0',
#        grad_fn=<SliceBackward0>)
# comparing total loss...
#  current_epoch[42] current_loss[6.827534377574921]   best_epoch[41] best_loss[2.20549988925457]
# test_total_err:  2.743755096197128
# [42/300] Loss_total: 6.82753 Test_loss: 2.74376 Time: 1.34s
# Test the score!
#
# In step 299, Pred_score1: tensor([0.9104], device='cuda:0', grad_fn=<SelectBackward0>), origin_score1: tensor([0.3341], device='cuda:0', grad_fn=<SelectBackward0>)
# origin_layout0: tensor([[0.2734, 0.5586, 1.0000, 1.0000],
# ...

# %% [markdown]
# ### 5. Layout Generation Test

# %%
# !python main.py --cfg cfg/layout_generator_test.yml --gpu 0
# Out:
# Using config:
# {'CONFIG_NAME': 'MultiLayer',
#  'CUDA': True,
#  'DATASET': 'gen',
#  'DATASET_NAME': 'layout',
#  'DATA_DIR': './data/MultiLayerDataset/GeneratorTestData',
#  'EVAL': {'EVAL_METRIC': 0,
#           'MODEL_EVALUATOR': './output_dir/EVALUATOR_layout_Model/Model/evaluator_best.pth',
#           'MODEL_GENERATOR': './output_dir/GENERATOR_layout_Model/Model/generator_best.pth',
#           'OUTPUT_DIR': './output_dir/GENERATOR_layout_Model',
#           'TEST_INDEX': 2},
#  'EVALUATOR': {'LR': 0.0001, 'WEIGHT_DECAY': 0.0005},
#  'GENERATOR': {'ALPHA': 20,
#                'BETA': 0,
#                'LOSS': '',
#                'LR': 0.0001,
#                'MAX_EPOCH': 0,
#                'WEIGHT_DECAY': 0.0005},
#  'GPU': '0',
#  'GT_DATA_DIR': './data/MultiLayerDataset/GroundLayer',
#  'INDICATOR_DIR': '',
#  'TRAIN': {'BATCH': False,
#            'BATCH_SIZE': 1,
#            'BIDIRECTIONAL': False,
#            'CONSTRAINT_RULES': [1, 2, 3, 4, 5],
# ...

# %% [markdown]
# ### 6. Layout Evaluator

# %%
# !python main.py --cfg cfg/layout_evaluator.yml --gpu 0
# Out:
# Streaming output truncated to the last 5000 lines.
# pred: 0.16708989441394806
# comparing total loss...
#  current_epoch[600] current_loss[5.043053567409515]   best_epoch[0] best_loss[0.0]
# [600/1600] Train_Loss_total: 5.0431 Test_Loss_total: 1.8043 Time: 1.4625s
# In epoch 601, pred_score1: tensor([0.1809], device='cuda:0', grad_fn=<SelectBackward0>), pred_score2: tensor([0.1357], device='cuda:0', grad_fn=<SelectBackward0>)
# pred: 0.17563940584659576
# comparing total loss...
#  current_epoch[601] current_loss[5.042554318904877]   best_epoch[0] best_loss[0.0]
# [601/1600] Train_Loss_total: 5.0426 Test_Loss_total: 1.8183 Time: 1.4225s
# In epoch 602, pred_score1: tensor([0.1574], device='cuda:0', grad_fn=<SelectBackward0>), pred_score2: tensor([0.1827], device='cuda:0', grad_fn=<SelectBackward0>)
# pred: 0.18595236539840698
# comparing total loss...
#  current_epoch[602] current_loss[5.042349994182587]   best_epoch[0] best_loss[0.0]
# ...

# %% [markdown]
# ### 7. Layout Evaluator Test

# %%
# !python main.py --cfg cfg/layout_evaluator_test.yml --gpu 0
# Out:
# Using config:
# {'CONFIG_NAME': 'MultiLayer',
#  'CUDA': True,
#  'DATASET': 'eval',
#  'DATASET_NAME': 'layout',
#  'DATA_DIR': './data/MultiLayerDataset',
#  'EVAL': {'EVAL_METRIC': 1,
#           'MODEL_EVALUATOR': 'Model/evaluator_best.pth',
#           'MODEL_GENERATOR': '',
#           'OUTPUT_DIR': './output_dir/EVALUATOR_layout_Model',
#           'TEST_INDEX': 1},
#  'EVALUATOR': {'LR': 0.0001, 'WEIGHT_DECAY': 0.0005},
#  'GENERATOR': {'ALPHA': 20,
#                'BETA': 0,
#                'LOSS': '',
#                'LR': 0.0001,
#                'MAX_EPOCH': 0,
#                'WEIGHT_DECAY': 0.0005},
#  'GPU': '0',
#  'GT_DATA_DIR': '',
#  'INDICATOR_DIR': '',
#  'TRAIN': {'BATCH': False,
#            'BATCH_SIZE': 1,
#            'BIDIRECTIONAL': False,
#            'CONSTRAINT_RULES': [1, 2, 3, 4, 5],
#            'EVALUATOR': '',
#            'FLAG': False,
#            'GENERATOR': False,
#            'GENERATOR_MODEL': '',
#            'MARGIN': 1.0,
# ...

# %% [markdown]
# ### 8. Generate random room layers from the profile of the ground layer (train data for the Generator)

# %%
# %cd dataset/GenerateData
# !python GenerateTrainData.py
# Out:
# [Errno 2] No such file or directory: 'dataset/GenerateData'
# /content/Project-Home-Mapper/LayoutGenerator_Lited/dataset/GenerateData
# save 1 layout is OK!
# pair_num:  50
# save 2 layout is OK!
# pair_num:  50
# save 3 layout is OK!
# pair_num:  50
# save 4 layout is OK!
# pair_num:  50
# save 5 layout is OK!
# pair_num:  50
# save 6 layout is OK!
# pair_num:  50
# save 7 layout is OK!
# pair_num:  50
# save 8 layout is OK!
# pair_num:  50
# save 9 layout is OK!
# pair_num:  50
# save 10 layout is OK!
# pair_num:  50
# save 11 layout is OK!
# pair_num:  50
# save 12 layout is OK!
# pair_num:  50
# save 13 layout is OK!
# pair_num:  50
# save 14 layout is OK!
# pair_num:  50
# save 15 layout is OK!
# pair_num:  50
# save 16 layout is OK!
# pair_num:  50
# save 17 layout is OK!
# pair_num:  50
# save 18 layout is OK!
# pair_num:  50
# save 19 layout is OK!
# pair_num:  50
# save 20 layout is OK!
# pair_num:  50
# save 21 layout is OK!
# pair_num:  50
# save 22 layout is OK!
# ...

# %% [markdown]
# ## Stage 2: Training & Testing Text_Generation_Lited

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/Project-Home-Mapper
# Out:
# /content/Project-Home-Mapper

# %%
# Download the dataset file
# !gdown --id 1n-tDLIMcYKk4hJAN8ueWtDHJ_fDhaz6A
# Unzip
# !unzip Text-to-3D-House-Model-Dataset.zip -d /content/Project-Home-Mapper/dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/semantic-expression/01250.txt
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/semantic-expression/01240.txt
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/label_withoutFA_rearrange/00926.png
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/semantic-expression/01265.txt
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/label_withoutFA_rearrange/00945.png
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/label_withoutFA_rearrange/00940.png
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/semantic-expression/01258.txt
#   inflating: /content/Project-Home-Mapper/dataset/Text-to-3D House Model/layout/semantic-expression/01248.txt
# ...

# %%
# %cd /content/Project-Home-Mapper/text_generation_Lited
# Out:
# /content/Project-Home-Mapper/text_generation_Lited

# %%
# !python main.py --texturePath=/content/Project-Home-Mapper/dataset/dataset/materials/ --ngf=80 --ndf=80 --zLoc=100 --zGL=31 --nDep=5 --nDepD=5 --batchSize=24 --niter=10000 --coeff_color_loss=0 --imageSize 160 --use_perceptual_loss=1
# Out:
# outputFolderolder results/materials/2025-07-13_09-42-33/
# Random Seed:  3063
# Load filenames from: /content/Project-Home-Mapper/dataset/dataset/materials/ID.txt (873)
# preparing training set ...
# Traceback (most recent call last):
#   File "/content/Project-Home-Mapper/text_generation_Lited/main.py", line 89, in <module>
#     dataloader, dataloader_test = data_loader()
#                                   ^^^^^^^^^^^^^
#   File "/content/Project-Home-Mapper/text_generation_Lited/main.py", line 67, in data_loader
#     dataset = TextureDataset(opt.texturePath, transformTex, opt.textureScale, train=True)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/Project-Home-Mapper/text_generation_Lited/util/utils.py", line 58, in __init__
#     material_color_apply_path = self.filenames[file_id]
#                                 ~~~~~~~~~~~~~~^^^^^^^^^
# KeyError: '(dp0'

# %% [markdown]
# ## Stage 3: GCN Model

# %%
# %cd /content/Project-Home-Mapper/bbox_gcn_Lited_postprocessing
# Out:
# /content/Project-Home-Mapper/bbox_gcn_Lited_postprocessing

# %%
# !python main.py --cfg cfg/layout.yml --gpu '0'
# Out:
# Traceback (most recent call last):
#   File "/content/Project-Home-Mapper/bbox_gcn_Lited_postprocessing/main.py", line 34, in <module>
#     cfg_from_file(args.cfg_file)
#   File "/content/Project-Home-Mapper/bbox_gcn_Lited_postprocessing/miscc/config.py", line 124, in cfg_from_file
#     yaml_cfg = edict(yaml.load(f))
#                      ^^^^^^^^^^^^
# TypeError: load() missing 1 required positional argument: 'Loader'

# %%
# !python main.py --cfg cfg/layout_test.yml --gpu '0'
# Out:
# Traceback (most recent call last):
#   File "/content/Project-Home-Mapper/bbox_gcn_Lited_postprocessing/main.py", line 34, in <module>
#     cfg_from_file(args.cfg_file)
#   File "/content/Project-Home-Mapper/bbox_gcn_Lited_postprocessing/miscc/config.py", line 124, in cfg_from_file
#     yaml_cfg = edict(yaml.load(f))
#                      ^^^^^^^^^^^^
# TypeError: load() missing 1 required positional argument: 'Loader'
